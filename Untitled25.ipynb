# %% [markdown]
# <a href="https://colab.research.google.com/github/ayahT/machinelearning/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
start_up = pd.read_csv('startup_funding.csv')
start_up
# Out:
#       Sr No Date dd/mm/yyyy                  Startup Name  \
# 0         1      09/01/2020                        BYJU’S
# 1         2      13/01/2020                        Shuttl
# 2         3      09/01/2020                     Mamaearth
# 3         4      02/01/2020  https://www.wealthbucket.in/
# 4         5      02/01/2020                        Fashor
# ...     ...             ...                           ...
# 3039   3040      29/01/2015                    Printvenue
# 3040   3041      29/01/2015                      Graphene
# 3041   3042      30/01/2015                Mad Street Den
# 3042   3043      30/01/2015                     Simplotel
# 3043   3044      31/01/2015              couponmachine.in
#
#         Industry Vertical                            SubVertical  \
# 0                  E-Tech                             E-learning
# 1          Transportation              App based shuttle service
# 2              E-commerce  Retailer of baby and toddler products
# ...

# %%
start_up.drop(["Sr No", "Remarks"], axis = 1, inplace = True)
start_up
# Out:
#      Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0         09/01/2020                        BYJU’S               E-Tech
# 1         13/01/2020                        Shuttl       Transportation
# 2         09/01/2020                     Mamaearth           E-commerce
# 3         02/01/2020  https://www.wealthbucket.in/              FinTech
# 4         02/01/2020                        Fashor  Fashion and Apparel
# ...              ...                           ...                  ...
# 3039      29/01/2015                    Printvenue                  NaN
# 3040      29/01/2015                      Graphene                  NaN
# 3041      30/01/2015                Mad Street Den                  NaN
# 3042      30/01/2015                     Simplotel                  NaN
# 3043      31/01/2015              couponmachine.in                  NaN
#
#                                 SubVertical City  Location  \
# ...

# %%
start_up = start_up[start_up['Industry Vertical'].notna()]
start_up
# Out:
#      Date dd/mm/yyyy                  Startup Name  \
# 0         09/01/2020                        BYJU’S
# 1         13/01/2020                        Shuttl
# 2         09/01/2020                     Mamaearth
# 3         02/01/2020  https://www.wealthbucket.in/
# 4         02/01/2020                        Fashor
# ...              ...                           ...
# 2868      29/04/2015                        Tracxn
# 2869      29/04/2015                          Dazo
# 2870      29/04/2015                      Tradelab
# 2871      29/04/2015                        PiQube
# 2872      29/04/2015               Travel Triangle
#
#                Industry Vertical                            SubVertical  \
# 0                         E-Tech                             E-learning
# 1                 Transportation              App based shuttle service
# 2                     E-commerce  Retailer of baby and toddler products
# ...

# %%
start_up.dropna(subset=['Date dd/mm/yyyy'], axis = 0, inplace = True)
start_up
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#      Date dd/mm/yyyy                  Startup Name  \
# 0         09/01/2020                        BYJU’S
# 1         13/01/2020                        Shuttl
# 2         09/01/2020                     Mamaearth
# 3         02/01/2020  https://www.wealthbucket.in/
# 4         02/01/2020                        Fashor
# ...              ...                           ...
# 2868      29/04/2015                        Tracxn
# 2869      29/04/2015                          Dazo
# 2870      29/04/2015                      Tradelab
# 2871      29/04/2015                        PiQube
# 2872      29/04/2015               Travel Triangle
#
# ...

# %%
start_up.count()
# Out:
# Date dd/mm/yyyy      2873
# Startup Name         2873
# Industry Vertical    2873
# SubVertical          2108
# City  Location       2864
# Investors Name       2849
# InvestmentnType      2869
# Amount in USD        1953
# dtype: int64

# %%
list2 = filter( lambda x: x.find( '.') != -1, start_up['Startup Name']  )
list(list2)
# Out:
# ['https://www.wealthbucket.in/',
#  'Lenskart.com',
#  'Sunstone Eduversity Pvt. Ltd',
#  'Sistema.bio',
#  'Vogo Automotive Pvt. Ltd.',
#  'Vyome Therapeutics Inc.',
#  'Samunnati Financial Intermediation & Services Pvt. Ltd',
#  'UrbanClap Technologies Pvt. Ltd',
#  'Veritas Finance Ltd.',
#  'Engineer.ai',
#  'Origo Commodities India Pvt. Ltd',
#  'Appario Retail Pvt Ltd.',
#  'IGP.com',
#  'Foyr.com',
#  'AadharAPI.com',
#  'Tilite Technologies Pvt. Ltd',
#  'Universal Sportsbiz Pvt. Ltd',
#  'Yatra.com',
#  'Upwardly.in',
#  'Autorox.co',
#  'Bottr.me',
#  'Gympik.com',
#  'eSahai.in',
#  'Boxx.ai',
#  'PeeSafe.in',
#  'Insider.in',
#  'Niki.ai',
#  'Vernacular.ai',
#  'Niki.ai',
#  'The Mons Co.',
#  'Stockroom.io',
#  'Hansel.io',
#  'Weddingz.in',
#  'Active.ai',
#  'numberz.in',
#  'Housing.com',
#  'Carcrew.in',
#  'Vithi.com',
#  'Faircent.com',
#  'Octo.ai',
#  'Grab.in',
#  'Fulfil.IO',
#  'Overcart.com',
#  'Oneway.cab',
#  'Active.ai',
#  'Niki.ai',
#  'Indi.com',
# ...

# %%
list3 = filter( lambda x: x.find( 'x') != -1, start_up['Date dd/mm/yyyy']  )
list(list3)
# Out:
# ['\\\\xc2\\\\xa010/7/2015']

# %%
start_up.replace({'Startup Name' : { 'https://www.wealthbucket.in/' : 'wealthbucket','.cab':'', '. Ltd.' : '', '. Ltd' : '', '.com' : '', '.in' : '' , '.ai' : '','.io':'' ,'.IO':'','.co':''}},inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1951: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[selected_item_labels] = value

# %%
d= list(start_up['Date dd/mm/yyyy'].str[-4:])
d
# Out:
# ['2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
# ...

# %%
start_up['Date dd/mm/yyyy']=d
start_up
# Out:
# <ipython-input-199-4451f8ff530c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   start_up['Date dd/mm/yyyy']=d
#      Date dd/mm/yyyy     Startup Name           Industry Vertical  \
# 0               2020           BYJU’S                      E-Tech
# 1               2020           Shuttl              Transportation
# 2               2020        Mamaearth                  E-commerce
# 3               2020     wealthbucket                     FinTech
# 4               2020           Fashor         Fashion and Apparel
# ...              ...              ...                         ...
# 2868            2015           Tracxn  Startup Analytics platform
# 2869            2015             Dazo    Mobile Food Ordering app
# ...

# %%
list2 = filter( lambda x: x.find( '/') != -1, start_up['Industry Vertical']  )
list(list2)
# Out:
# ['Community Driven News/Views Platform',
#  'CRM / Analytics platform',
#  'Private Jet/ Helicopter Marketplace',
#  'Ethnic/ Traditional Fashion Store',
#  'Artist / Designer Marketplace',
#  'IT / Customer Engagement Consulting',
#  'Marketing / Advertising Automation platform',
#  'Digital / Mobile Wallet',
#  'Digital / Mobile Wallet',
#  'Hyper-Local Online/Mobile Grocery',
#  'Hyper-Local Online/Mobile Grocery',
#  'Online / Mobile Customer Support',
#  'Tele-Shopping / eCommerce',
#  'Used Gadgets Buy / Refurbishing']

# %%
start_up['SubVertical'].isnull()
nan_in_col = start_up[start_up['SubVertical'].isnull()]
nan_in_col
# Out:
#      Date dd/mm/yyyy               Startup Name  \
# 2108            2015               CollegeDekho
# 2109            2015  Black White Orange Brands
# 2110            2015                   Biteclub
# 2111            2015            Patel Logistics
# 2112            2015                      Wigzo
# ...              ...                        ...
# 2868            2015                     Tracxn
# 2869            2015                       Dazo
# 2870            2015                   Tradelab
# 2871            2015                     PiQube
# 2872            2015            Travel Triangle
#
#                                Industry Vertical SubVertical City  Location  \
# 2108       Online Education Information platform         NaN         Jaipur
# 2109                     Brand Licensing Startup         NaN         Mumbai
# 2110  Gourmet Food Discovery & Delivery platform         NaN        Gurgaon
# 2111         Transportation & Logistics Platform         NaN         Mumbai
# ...

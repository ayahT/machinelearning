# %% [markdown]
# <a href="https://colab.research.google.com/github/ayahT/machinelearning/blob/main/firstpart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mushrooms = pd.read_csv('mushrooms.csv')
mushrooms
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape stalk-root  \
# ...

# %%
mushrooms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
pd.set_option('display.max_columns', mushrooms.columns.size)
mushrooms.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color stalk-shape stalk-root  \
# count          8124      8124       8124        8124       8124
# unique            2         2         12           2          5
# top               c         b          b           t          b
# freq           6812      5612       1728        4608       3776
#
#        stalk-surface-above-ring stalk-surface-below-ring  \
# count                      8124                     8124
# unique                        4                        4
# top                           s                        s
# ...

# %%
list_of_column_names = list(mushrooms.columns)
all_unique=[]
list_of_column_names
for i in list_of_column_names:
  data=mushrooms.loc[:,i]
  all_unique.append(list(data.unique()))
  print(i,data.unique())
# Out:
# class ['p' 'e']
# cap-shape ['x' 'b' 's' 'f' 'k' 'c']
# cap-surface ['s' 'y' 'f' 'g']
# cap-color ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# bruises ['t' 'f']
# odor ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
# gill-attachment ['f' 'a']
# gill-spacing ['c' 'w']
# gill-size ['n' 'b']
# gill-color ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']
# stalk-shape ['e' 't']
# stalk-root ['e' 'c' 'b' 'r' '?']
# stalk-surface-above-ring ['s' 'f' 'k' 'y']
# stalk-surface-below-ring ['s' 'f' 'y' 'k']
# stalk-color-above-ring ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# stalk-color-below-ring ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# veil-type ['p']
# veil-color ['w' 'n' 'o' 'y']
# ring-number ['o' 't' 'n']
# ring-type ['p' 'e' 'l' 'f' 'n']
# spore-print-color ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']
# population ['s' 'n' 'a' 'v' 'y' 'c']
# habitat ['u' 'g' 'm' 'd' 'p' 'w' 'l']

# %%
# list_of_column_names = list(mushrooms.columns)
# for i in range(len(list_of_column_names)):
#   for j in all_unique[i]:
#     mushrooms.replace(to_replace=j,
#            value=ord(j),inplace = True) 
# mushrooms

# %%
# corr=mushrooms.corr()
# ord('p')

# %%
# plt.subplots(figsize=(25,25))
# sns.heatmap(corr,cmap="RdBu",vmin=-1,vmax=1,annot=True,annot_kws={'fontsize':13})

# %%
list_of_column_name = list(mushrooms.columns)

# %%
poisonous=mushrooms[mushrooms['class']=='p']
poisonous
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 3        p         x           y         w       t    p               f
# 8        p         x           y         w       t    p               f
# 13       p         x           y         w       t    p               f
# 17       p         x           s         n       t    p               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8114     p         f           y         c       f    m               a
# 8116     p         k           y         n       f    s               f
# 8117     p         k           s         e       f    y               f
# 8118     p         k           y         n       f    f               f
# 8122     p         k           y         n       f    y               f
#
#      gill-spacing gill-size gill-color stalk-shape stalk-root  \
# ...

# %%
mushrooms['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
list_of_column_name = list(mushrooms.columns)
lists=[]
for i in list_of_column_name:
 lists.append(dict(poisonous[i].value_counts()))
lists
# Out:
# [{'p': 3916},
#  {'x': 1708, 'f': 1556, 'k': 600, 'b': 48, 'c': 4},
#  {'y': 1740, 's': 1412, 'f': 760, 'g': 4},
#  {'n': 1020,
#   'e': 876,
#   'g': 808,
#   'y': 672,
#   'w': 320,
#   'b': 120,
#   'p': 88,
#   'c': 12},
#  {'f': 3292, 't': 624},
#  {'f': 2160, 'y': 576, 's': 576, 'p': 256, 'c': 192, 'n': 120, 'm': 36},
#  {'f': 3898, 'a': 18},
#  {'c': 3804, 'w': 112},
#  {'n': 2224, 'b': 1692},
#  {'b': 1728,
#   'p': 640,
#   'h': 528,
#   'g': 504,
#   'w': 246,
#   'n': 112,
#   'k': 64,
#   'u': 48,
#   'r': 24,
#   'y': 22},
#  {'t': 2016, 'e': 1900},
#  {'b': 1856, '?': 1760, 'e': 256, 'c': 44},
#  {'k': 2228, 's': 1536, 'f': 144, 'y': 8},
#  {'k': 2160, 's': 1536, 'f': 144, 'y': 76},
#  {'w': 1712, 'p': 1296, 'n': 432, 'b': 432, 'c': 36, 'y': 8},
#  {'w': 1680, 'p': 1296, 'n': 448, 'b': 432, 'c': 36, 'y': 24},
#  {'p': 3916},
#  {'w': 3908, 'y': 8},
#  {'o': 3808, 't': 72, 'n': 36},
#  {'e': 1768, 'l': 1296, 'p': 816, 'n': 36},
# ...

# %%
# corrpoisonous=poisonous.corr()
# corrpoisonous

# %%
# plt.subplots(figsize=(20,20))

# sns.heatmap(corrpoisonous,cmap="YlGnBu",vmin=-1,vmax=1,annot=True,annot_kws={'fontsize':10})

# %%
# Class=mushrooms.loc[:,'class']
# Class.unique()
# cap_shape=mushrooms.loc[:,'cap-shape']
# cap_shape.unique()
# cap_surface=mushrooms.loc[:,'cap-surface']
# cap_surface.unique()
# cap_color=mushrooms.loc[:,'cap-color']
# cap_color.unique()
# bruises=mushrooms.loc[:,'bruises']
# bruises.unique()
# odor=mushrooms.loc[:,'odor']
# odor.unique()
# gill_attachment=mushrooms.loc[:,'gill-attachment']
# gill_attachment.unique()
# gill_spacing=mushrooms.loc[:,'gill-spacing']
# gill_spacing.unique()
# gill_size=mushrooms.loc[:,'gill-size']
# gill_size.unique()
# gill_color=mushrooms.loc[:,'gill-color']
# gill_color.unique()
# population=mushrooms.loc[:,'population']
# population.unique()
# habitat=mushrooms.loc[:,'habitat']
# habitat.unique()

# %%
# stalk_shape=mushrooms.loc[:,'stalk-shape']
# stalk_shape.unique()
# stalk_root=mushrooms.loc[:,'stalk-root']
# stalk_root.unique()
# stalk_surface_above_ring=mushrooms.loc[:,'stalk-surface-above-ring']
# stalk_surface_above_ring.unique()
# stalk_surface_below_ring=mushrooms.loc[:,'stalk-surface-below-ring']
# stalk_surface_below_ring.unique()
# stalk_color_above_ring=mushrooms.loc[:,'stalk-color-above-ring']
# stalk_color_above_ring.unique()
# stalk_color_below_ring=mushrooms.loc[:,'stalk-color-below-ring']
# stalk_color_below_ring.unique()
# veil_type=mushrooms.loc[:,'veil-type']
# veil_type.unique()
# veil_color=mushrooms.loc[:,'veil-color']
# veil_color.unique()
# ring_number=mushrooms.loc[:,'ring-number']
# ring_number.unique()
# ring_type=mushrooms.loc[:,'ring-type']
# ring_type.unique()
# spore_print_color=mushrooms.loc[:,'spore-print-color']
# spore_print_color.unique()
